# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_data = pd.read_excel(r"C:\Users\ramya\Downloads\Data_Train.xlsx")

# %%
train_data.head(4)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218

# %%
train_data.tail(4)
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time Arrival_Time Duration Total_Stops  \
# 10679              CCU → BLR    20:45        23:20   2h 35m    non-stop
# 10680              BLR → DEL    08:20        11:20       3h    non-stop
# 10681              BLR → DEL    11:30        14:10   2h 40m    non-stop
# 10682  DEL → GOI → BOM → COK    10:55        19:15   8h 20m     2 stops
#
#       Additional_Info  Price
# 10679         No info   4145
# 10680         No info   7229
# 10681         No info  12648
# 10682         No info  11753

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
train_data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              1
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        1
# Additional_Info    0
# Price              0
# dtype: int64

# %%
train_data['Total_Stops'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10678    False
# 10679    False
# 10680    False
# 10681    False
# 10682    False
# Name: Total_Stops, Length: 10683, dtype: bool

# %%
train_data[train_data['Total_Stops'].isnull()]
# Out:
#         Airline Date_of_Journey Source Destination Route Dep_Time  \
# 9039  Air India       6/05/2019  Delhi      Cochin   NaN    09:45
#
#       Arrival_Time Duration Total_Stops Additional_Info  Price
# 9039  09:25 07 May  23h 40m         NaN         No info   7480

# %%
train_data.dropna(inplace=True)

# %%
train_data.isnull().sum()
# Out:
# Airline            0
# Date_of_Journey    0
# Source             0
# Destination        0
# Route              0
# Dep_Time           0
# Arrival_Time       0
# Duration           0
# Total_Stops        0
# Additional_Info    0
# Price              0
# dtype: int64

# %%
data = train_data.copy()

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
def change_into_Datetime(col):
    data[col] = pd.to_datetime(data[col])

# %%
import warnings
from warnings import filterwarnings
filterwarnings("ignore")

# %%
for feature in ['Dep_Time','Arrival_Time','Date_of_Journey']:
    change_into_Datetime(feature)

# %%
data.dtypes
# Out:
# Airline                    object
# Date_of_Journey    datetime64[ns]
# Source                     object
# Destination                object
# Route                      object
# Dep_Time           datetime64[ns]
# Arrival_Time       datetime64[ns]
# Duration                   object
# Total_Stops                object
# Additional_Info            object
# Price                       int64
# dtype: object

# %%
data['Date_of_Journey'].dt

# %%
data["Journey_month"] = data['Date_of_Journey'].dt.month

# %%
data["Journey_day"] = data['Date_of_Journey'].dt.day

# %%
data["Journey_year"] = data['Date_of_Journey'].dt.year

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-05-12   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-03-01  Banglore   New Delhi        BLR → NAG → DEL
#
#              Dep_Time        Arrival_Time Duration Total_Stops  \
# 0 2025-11-28 22:20:00 2025-03-22 01:10:00   2h 50m    non-stop
# 1 2025-11-28 05:50:00 2025-11-28 13:15:00   7h 25m     2 stops
# 2 2025-11-28 09:25:00 2025-06-10 04:25:00      19h     2 stops
# 3 2025-11-28 18:05:00 2025-11-28 23:30:00   5h 25m      1 stop
# 4 2025-11-28 16:50:00 2025-11-28 21:35:00   4h 45m      1 stop
#
#   Additional_Info  Price  Journey_month  Journey_day  Journey_year
# 0         No info   3897              3           24          2019
# 1         No info   7662              5            1          2019
# 2         No info  13882              6            9          2019
# 3         No info   6218              5           12          2019
# 4         No info  13302              3            1          2019

# %%
def extract_hour_min(df, col):
    df[col+"_hour"] = df[col].dt.hour
    df[col+"_minute"] = df[col].dt.minute
    return df.head(3)

# %%
extract_hour_min(data, "Dep_Time")
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
#
#              Dep_Time        Arrival_Time Duration Total_Stops  \
# 0 2025-11-28 22:20:00 2025-03-22 01:10:00   2h 50m    non-stop
# 1 2025-11-28 05:50:00 2025-11-28 13:15:00   7h 25m     2 stops
# 2 2025-11-28 09:25:00 2025-06-10 04:25:00      19h     2 stops
#
#   Additional_Info  Price  Journey_month  Journey_day  Journey_year  \
# 0         No info   3897              3           24          2019
# 1         No info   7662              5            1          2019
# 2         No info  13882              6            9          2019
#
#    Dep_Time_hour  Dep_Time_minute
# 0             22               20
# 1              5               50
# 2              9               25

# %%
extract_hour_min(data, "Arrival_Time")
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
#
#              Dep_Time        Arrival_Time Duration Total_Stops  \
# 0 2025-11-28 22:20:00 2025-03-22 01:10:00   2h 50m    non-stop
# 1 2025-11-28 05:50:00 2025-11-28 13:15:00   7h 25m     2 stops
# 2 2025-11-28 09:25:00 2025-06-10 04:25:00      19h     2 stops
#
#   Additional_Info  Price  Journey_month  Journey_day  Journey_year  \
# 0         No info   3897              3           24          2019
# 1         No info   7662              5            1          2019
# 2         No info  13882              6            9          2019
#
#    Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  Arrival_Time_minute
# 0             22               20                  1                   10
# 1              5               50                 13                   15
# 2              9               25                  4                   25

# %%
data.drop(["Dep_Time", "Arrival_Time"], axis=1, inplace=True)

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Duration', 'Total_Stops', 'Additional_Info', 'Price', 'Journey_month',
#        'Journey_day', 'Journey_year', 'Dep_Time_hour', 'Dep_Time_minute',
#        'Arrival_Time_hour', 'Arrival_Time_minute'],
#       dtype='object')

# %%
data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      2019-05-12   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      2019-03-01  Banglore   New Delhi        BLR → NAG → DEL
#
#   Duration Total_Stops Additional_Info  Price  Journey_month  Journey_day  \
# 0   2h 50m    non-stop         No info   3897              3           24
# 1   7h 25m     2 stops         No info   7662              5            1
# 2      19h     2 stops         No info  13882              6            9
# 3   5h 25m      1 stop         No info   6218              5           12
# 4   4h 45m      1 stop         No info  13302              3            1
#
#    Journey_year  Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  \
# 0          2019             22               20                  1
# 1          2019              5               50                 13
# 2          2019              9               25                  4
# 3          2019             18                5                 23
# 4          2019             16               50                 21
#
#    Arrival_Time_minute
# 0                   10
# 1                   15
# 2                   25
# 3                   30
# 4                   35

# %%
data.shape
# Out:
# (10682, 16)

# %%
def flight_dep_time(x):
    if (x>4) and (x<=8):
        return "Early Morning"
    elif (x>8) and (x<=12):
        return "Morning"
    elif (x>12) and (x<=16):
        return "Afternoon"
    elif (x>16) and (x<=20):
        return "Evening"
    elif (x>20) and (x<=24):
        return "Night"
    else:
        return "late night"

# %%
data["Dep_Time_hour"].apply(flight_dep_time).value_counts()
# Out:
# Dep_Time_hour
# Early Morning    2880
# Evening          2357
# Morning          2209
# Afternoon        1731
# Night            1040
# late night        465
# Name: count, dtype: int64

# %%
data["Dep_Time_hour"].apply(flight_dep_time).value_counts().plot()   #inbuild pandas plot
# Out:
# <Axes: xlabel='Dep_Time_hour'>

# %%
data["Dep_Time_hour"].apply(flight_dep_time).value_counts().plot(kind="bar", color='g')
# Out:
# <Axes: xlabel='Dep_Time_hour'>

# %%
# !pip install plotly
# !pip install chart_studio
# Out:
# Requirement already satisfied: plotly in c:\users\ramya\anaconda3\lib\site-packages (5.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\ramya\anaconda3\lib\site-packages (from plotly) (8.2.2)
# Requirement already satisfied: chart_studio in c:\users\ramya\anaconda3\lib\site-packages (1.1.0)
# Requirement already satisfied: plotly in c:\users\ramya\anaconda3\lib\site-packages (from chart_studio) (5.9.0)
# Requirement already satisfied: requests in c:\users\ramya\anaconda3\lib\site-packages (from chart_studio) (2.31.0)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\ramya\anaconda3\lib\site-packages (from chart_studio) (1.4.2)
# Requirement already satisfied: six in c:\users\ramya\anaconda3\lib\site-packages (from chart_studio) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\ramya\anaconda3\lib\site-packages (from plotly->chart_studio) (8.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ramya\anaconda3\lib\site-packages (from requests->chart_studio) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ramya\anaconda3\lib\site-packages (from requests->chart_studio) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ramya\anaconda3\lib\site-packages (from requests->chart_studio) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ramya\anaconda3\lib\site-packages (from requests->chart_studio) (2025.11.12)

# %%
# !pip install cufflinks
# Out:
# Requirement already satisfied: cufflinks in c:\users\ramya\anaconda3\lib\site-packages (0.17.3)
# Requirement already satisfied: numpy>=1.9.2 in c:\users\ramya\anaconda3\lib\site-packages (from cufflinks) (1.24.4)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\ramya\anaconda3\lib\site-packages (from cufflinks) (2.0.3)
# Requirement already satisfied: plotly>=4.1.1 in c:\users\ramya\anaconda3\lib\site-packages (from cufflinks) (5.9.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\ramya\anaconda3\lib\site-packages (from cufflinks) (1.16.0)
# Requirement already satisfied: colorlover>=0.2.1 in c:\users\ramya\anaconda3\lib\site-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: setuptools>=34.4.1 in c:\users\ramya\anaconda3\lib\site-packages (from cufflinks) (80.9.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\ramya\anaconda3\lib\site-packages (from cufflinks) (8.15.0)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\ramya\anaconda3\lib\site-packages (from cufflinks) (8.0.4)
# Requirement already satisfied: backcall in c:\users\ramya\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.2.0)
# Requirement already satisfied: decorator in c:\users\ramya\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ramya\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\ramya\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\ramya\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\ramya\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ramya\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\ramya\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\ramya\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.7.1)
# Requirement already satisfied: colorama in c:\users\ramya\anaconda3\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.4.6)
# Requirement already satisfied: wcwidth in c:\users\ramya\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.3.0->cufflinks) (0.2.5)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\ramya\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (6.25.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\ramya\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\ramya\anaconda3\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.0.5)
# Requirement already satisfied: comm>=0.1.1 in c:\users\ramya\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\ramya\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\ramya\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\ramya\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (5.3.0)
# Requirement already satisfied: nest-asyncio in c:\users\ramya\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (1.5.6)
# Requirement already satisfied: packaging in c:\users\ramya\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (23.1)
# Requirement already satisfied: psutil in c:\users\ramya\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in c:\users\ramya\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\ramya\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (6.3.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\ramya\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=5.3.0->cufflinks) (0.8.3)
# Requirement already satisfied: entrypoints in c:\users\ramya\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ramya\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\ramya\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\ramya\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks) (305.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ramya\anaconda3\lib\site-packages (from pandas>=0.19.2->cufflinks) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ramya\anaconda3\lib\site-packages (from pandas>=0.19.2->cufflinks) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\ramya\anaconda3\lib\site-packages (from plotly>=4.1.1->cufflinks) (8.2.2)
# Requirement already satisfied: executing in c:\users\ramya\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->cufflinks) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\ramya\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->cufflinks) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\ramya\anaconda3\lib\site-packages (from stack-data->ipython>=5.3.0->cufflinks) (0.2.2)

# %%
import plotly 
import cufflinks as cf
from cufflinks.offline import go_offline
from plotly.offline import plot, iplot, init_notebook_mode, download_plotlyjs
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
def preprocess_duration (x):
    if 'h' not in x:
        x = '0h' + ' ' + x
    elif 'm' not in x:
        x = x + ' ' + '0m'
    return x

# %%
data['Duration'].apply(preprocess_duration)
# Out:
# 0        2h 50m
# 1        7h 25m
# 2        19h 0m
# 3        5h 25m
# 4        4h 45m
#           ...
# 10678    2h 30m
# 10679    2h 35m
# 10680     3h 0m
# 10681    2h 40m
# 10682    8h 20m
# Name: Duration, Length: 10682, dtype: object

# %%
data['Duration'] = data['Duration'].apply(preprocess_duration)

# %%
data['Duration'][0]
# Out:
# '2h 50m'

# %%
'2h 50m'.split(' ')
# Out:
# ['2h', '50m']

# %%
'2h 50m'.split(' ')[0][0:-1]
# Out:
# '2'

# %%
int('2h 50m'.split(' ')[0][0:-1])
# Out:
# 2

# %%
data['Duration_hours'] = data['Duration'].apply(lambda x : int(x.split(' ')[0][0:-1]))

# %%
data['Duration_mins'] = data['Duration'].apply(lambda x : int(x.split(' ')[1][0:-1]))

# %%
data.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1  Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Duration Total_Stops Additional_Info  Price  Journey_month  Journey_day  \
# 0   2h 50m    non-stop         No info   3897              3           24
# 1   7h 25m     2 stops         No info   7662              5            1
#
#    Journey_year  Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  \
# 0          2019             22               20                  1
# 1          2019              5               50                 13
#
#    Arrival_Time_minute  Duration_hours  Duration_mins
# 0                   10               2             50
# 1                   15               7             25

# %%
eval('2*60')
# Out:
# 120

# %%
data['Duration_total_mins'] = data['Duration'].str.replace('h', "*60").str.replace(' ','+').str.replace('m', "*1").apply(eval)

# %%
data['Duration_total_mins']
# Out:
# 0         170
# 1         445
# 2        1140
# 3         325
# 4         285
#          ...
# 10678     150
# 10679     155
# 10680     180
# 10681     160
# 10682     500
# Name: Duration_total_mins, Length: 10682, dtype: int64

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Duration', 'Total_Stops', 'Additional_Info', 'Price', 'Journey_month',
#        'Journey_day', 'Journey_year', 'Dep_Time_hour', 'Dep_Time_minute',
#        'Arrival_Time_hour', 'Arrival_Time_minute', 'Duration_hours',
#        'Duration_mins', 'Duration_total_mins'],
#       dtype='object')

# %%
sns.scatterplot(x="Duration_total_mins", y="Price", data=data)
# Out:
# <Axes: xlabel='Duration_total_mins', ylabel='Price'>

# %%
sns.lmplot(x="Duration_total_mins", y="Price", data=data)      #regression

# %%
sns.scatterplot(x="Duration_total_mins", y="Price", hue="Total_Stops", data=data)
# Out:
# <Axes: xlabel='Duration_total_mins', ylabel='Price'>

# %%
data['Airline']=='Jet Airways'
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 10678    False
# 10679    False
# 10680     True
# 10681    False
# 10682    False
# Name: Airline, Length: 10682, dtype: bool

# %%
data[data['Airline']=='Jet Airways'].groupby('Route').size()
# Out:
# Route
# BLR → BDQ → DEL            8
# BLR → BOM → DEL          385
# BLR → BOM → JDH → DEL      3
# BLR → DEL                382
# BLR → MAA → DEL           10
# BOM → BDQ → DEL → HYD      2
# BOM → DED → DEL → HYD      1
# BOM → DEL → HYD            5
# BOM → HYD                207
# BOM → IDR → DEL → HYD      1
# BOM → JDH → DEL → HYD      1
# BOM → UDR → DEL → HYD      1
# BOM → VNS → DEL → HYD      1
# CCU → BOM → BLR          930
# CCU → BOM → PNQ → BLR      4
# CCU → DEL → BLR          300
# CCU → GAU → BLR           22
# DEL → AMD → BOM → COK    141
# DEL → ATQ → BOM → COK     38
# DEL → BDQ → BOM → COK     28
# DEL → BHO → BOM → COK     29
# DEL → BOM → COK          875
# DEL → CCU → BOM → COK      1
# DEL → COK                 34
# DEL → DED → BOM → COK      2
# DEL → IDR → BOM → COK     86
# DEL → IXC → BOM → COK     13
# DEL → JAI → BOM → COK    207
# DEL → JDH → BOM → COK     23
# DEL → LKO → BOM → COK     25
# DEL → MAA → BOM → COK     16
# DEL → NAG → BOM → COK     61
# DEL → UDR → BOM → COK      7
# dtype: int64

# %%
data[data['Airline']=='Jet Airways'].groupby('Route').size().sort_values(ascending=False)
# Out:
# Route
# CCU → BOM → BLR          930
# DEL → BOM → COK          875
# BLR → BOM → DEL          385
# BLR → DEL                382
# CCU → DEL → BLR          300
# BOM → HYD                207
# DEL → JAI → BOM → COK    207
# DEL → AMD → BOM → COK    141
# DEL → IDR → BOM → COK     86
# DEL → NAG → BOM → COK     61
# DEL → ATQ → BOM → COK     38
# DEL → COK                 34
# DEL → BHO → BOM → COK     29
# DEL → BDQ → BOM → COK     28
# DEL → LKO → BOM → COK     25
# DEL → JDH → BOM → COK     23
# CCU → GAU → BLR           22
# DEL → MAA → BOM → COK     16
# DEL → IXC → BOM → COK     13
# BLR → MAA → DEL           10
# BLR → BDQ → DEL            8
# DEL → UDR → BOM → COK      7
# BOM → DEL → HYD            5
# CCU → BOM → PNQ → BLR      4
# BLR → BOM → JDH → DEL      3
# DEL → DED → BOM → COK      2
# BOM → BDQ → DEL → HYD      2
# DEL → CCU → BOM → COK      1
# BOM → VNS → DEL → HYD      1
# BOM → UDR → DEL → HYD      1
# BOM → JDH → DEL → HYD      1
# BOM → IDR → DEL → HYD      1
# BOM → DED → DEL → HYD      1
# dtype: int64

# %%
sns.boxplot(y='Price', x='Airline', data=data.sort_values('Price', ascending=False))
plt.xticks(rotation="vertical")
plt.show()

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Duration', 'Total_Stops', 'Additional_Info', 'Price', 'Journey_month',
#        'Journey_day', 'Journey_year', 'Dep_Time_hour', 'Dep_Time_minute',
#        'Arrival_Time_hour', 'Arrival_Time_minute', 'Duration_hours',
#        'Duration_mins', 'Duration_total_mins'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Duration', 'Total_Stops', 'Additional_Info', 'Price', 'Journey_month',
#        'Journey_day', 'Journey_year', 'Dep_Time_hour', 'Dep_Time_minute',
#        'Arrival_Time_hour', 'Arrival_Time_minute', 'Duration_hours',
#        'Duration_mins', 'Duration_total_mins'],
#       dtype='object')

# %%
cat_col = [col for col in data.columns if data[col].dtype=="object"]

# %%
num_col = [col for col in data.columns if data[col].dtype!="object"]

# %%
cat_col
# Out:
# ['Airline',
#  'Source',
#  'Destination',
#  'Route',
#  'Duration',
#  'Total_Stops',
#  'Additional_Info']

# %%
data['Source'].unique()
# Out:
# array(['Banglore', 'Kolkata', 'Delhi', 'Chennai', 'Mumbai'], dtype=object)

# %%
data['Source'].apply(lambda X:1 if X=='Banglore' else 0)
# Out:
# 0        1
# 1        0
# 2        0
# 3        0
# 4        1
#         ..
# 10678    0
# 10679    0
# 10680    1
# 10681    1
# 10682    0
# Name: Source, Length: 10682, dtype: int64

# %%
for sub_Category in data['Source'].unique():
    data['Source_'+sub_Category] = data['Source'].apply(lambda X:1 if X=='sub_Category' else 0)

# %%
data.head(3)
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      2019-03-24  Banglore   New Delhi              BLR → DEL
# 1    Air India      2019-05-01   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways      2019-06-09     Delhi      Cochin  DEL → LKO → BOM → COK
#
#   Duration Total_Stops Additional_Info  Price  Journey_month  ...  \
# 0   2h 50m    non-stop         No info   3897              3  ...
# 1   7h 25m     2 stops         No info   7662              5  ...
# 2   19h 0m     2 stops         No info  13882              6  ...
#
#    Arrival_Time_hour  Arrival_Time_minute  Duration_hours  Duration_mins  \
# 0                  1                   10               2             50
# 1                 13                   15               7             25
# 2                  4                   25              19              0
#
#    Duration_total_mins  Source_Banglore  Source_Kolkata  Source_Delhi  \
# 0                  170                0               0             0
# 1                  445                0               0             0
# 2                 1140                0               0             0
#
#    Source_Chennai  Source_Mumbai
# 0               0              0
# 1               0              0
# 2               0              0
#
# [3 rows x 24 columns]

# %%
cat_col
# Out:
# ['Airline',
#  'Source',
#  'Destination',
#  'Route',
#  'Duration',
#  'Total_Stops',
#  'Additional_Info']

# %%
data['Airline'].nunique()
# Out:
# 12

# %%
data.groupby(['Airline'])['Price'].mean().sort_values()
# Out:
# Airline
# Trujet                                4140.000000
# SpiceJet                              4338.284841
# Air Asia                              5590.260188
# IndiGo                                5673.682903
# GoAir                                 5861.056701
# Vistara                               7796.348643
# Vistara Premium economy               8962.333333
# Air India                             9612.427756
# Multiple carriers                    10902.678094
# Multiple carriers Premium economy    11418.846154
# Jet Airways                          11643.923357
# Jet Airways Business                 58358.666667
# Name: Price, dtype: float64

# %%
airlines = data.groupby(['Airline'])['Price'].mean().sort_values().index

# %%
airlines
# Out:
# Index(['Trujet', 'SpiceJet', 'Air Asia', 'IndiGo', 'GoAir', 'Vistara',
#        'Vistara Premium economy', 'Air India', 'Multiple carriers',
#        'Multiple carriers Premium economy', 'Jet Airways',
#        'Jet Airways Business'],
#       dtype='object', name='Airline')

# %%
dict_airlines = {key:index for index, key in enumerate(airlines, 0)}

# %%
dict_airlines
# Out:
# {'Trujet': 0,
#  'SpiceJet': 1,
#  'Air Asia': 2,
#  'IndiGo': 3,
#  'GoAir': 4,
#  'Vistara': 5,
#  'Vistara Premium economy': 6,
#  'Air India': 7,
#  'Multiple carriers': 8,
#  'Multiple carriers Premium economy': 9,
#  'Jet Airways': 10,
#  'Jet Airways Business': 11}

# %%
data['Airline'] = data['Airline'].map(dict_airlines)

# %%
data['Airline']
# Out:
# 0         3
# 1         7
# 2        10
# 3         3
# 4         3
#          ..
# 10678     2
# 10679     7
# 10680    10
# 10681     5
# 10682     7
# Name: Airline, Length: 10682, dtype: int64

# %%
data['Destination'].unique()
# Out:
# array(['New Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Delhi', 'Hyderabad'],
#       dtype=object)

# %%
data['Destination'].replace('New Delhi', 'Delhi', inplace=True)

# %%
data['Destination'].unique()
# Out:
# array(['Delhi', 'Banglore', 'Cochin', 'Kolkata', 'Hyderabad'],
#       dtype=object)

# %%
dest = data.groupby(['Destination'])['Price'].mean().sort_values().index

# %%
dest
# Out:
# Index(['Kolkata', 'Hyderabad', 'Delhi', 'Banglore', 'Cochin'], dtype='object', name='Destination')

# %%
dict_dest = {key:index for index, key in enumerate(dest, 0)}

# %%
dict_dest
# Out:
# {'Kolkata': 0, 'Hyderabad': 1, 'Delhi': 2, 'Banglore': 3, 'Cochin': 4}

# %%
data['Destination'] = data['Destination'].map(dict_dest)

# %%
data['Destination']
# Out:
# 0        2
# 1        3
# 2        4
# 3        3
# 4        2
#         ..
# 10678    3
# 10679    3
# 10680    2
# 10681    2
# 10682    4
# Name: Destination, Length: 10682, dtype: int64

# %%
data['Total_Stops'].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', '4 stops'],
#       dtype=object)

# %%
stop = {'non-stop':0, '2 stops':2, '1 stop':1, '3 stops':3, '4 stops':4}

# %%
data['Total_Stops'] = data['Total_Stops'].map(stop)

# %%
data['Total_Stops']
# Out:
# 0        0
# 1        2
# 2        2
# 3        1
# 4        1
#         ..
# 10678    0
# 10679    0
# 10680    0
# 10681    0
# 10682    2
# Name: Total_Stops, Length: 10682, dtype: int64

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Duration', 'Total_Stops', 'Additional_Info', 'Price', 'Journey_month',
#        'Journey_day', 'Journey_year', 'Dep_Time_hour', 'Dep_Time_minute',
#        'Arrival_Time_hour', 'Arrival_Time_minute', 'Duration_hours',
#        'Duration_mins', 'Duration_total_mins', 'Source_Banglore',
#        'Source_Kolkata', 'Source_Delhi', 'Source_Chennai', 'Source_Mumbai'],
#       dtype='object')

# %%
data['Additional_Info'].value_counts()/len(data)*100
# Out:
# Additional_Info
# No info                         78.112713
# In-flight meal not included     18.554578
# No check-in baggage included     2.995694
# 1 Long layover                   0.177869
# Change airports                  0.065531
# Business class                   0.037446
# No Info                          0.028085
# 1 Short layover                  0.009362
# Red-eye flight                   0.009362
# 2 Long layover                   0.009362
# Name: count, dtype: float64

# %%
data['Journey_year'].unique()
# Out:
# array([2019])

# %%
data.drop(columns=['Date_of_Journey', 'Additional_Info', 'Source', 'Journey_year', 'Duration_total_mins', 'Route'], axis=1, inplace=True)

# %%
data.columns
# Out:
# Index(['Airline', 'Destination', 'Duration', 'Total_Stops', 'Price',
#        'Journey_month', 'Journey_day', 'Dep_Time_hour', 'Dep_Time_minute',
#        'Arrival_Time_hour', 'Arrival_Time_minute', 'Duration_hours',
#        'Duration_mins', 'Source_Banglore', 'Source_Kolkata', 'Source_Delhi',
#        'Source_Chennai', 'Source_Mumbai'],
#       dtype='object')

# %%
data.drop(columns=['Duration'], axis=1, inplace=True)

# %%
data.head(3)
# Out:
#    Airline  Destination  Total_Stops  Price  Journey_month  Journey_day  \
# 0        3            2            0   3897              3           24
# 1        7            3            2   7662              5            1
# 2       10            4            2  13882              6            9
#
#    Dep_Time_hour  Dep_Time_minute  Arrival_Time_hour  Arrival_Time_minute  \
# 0             22               20                  1                   10
# 1              5               50                 13                   15
# 2              9               25                  4                   25
#
#    Duration_hours  Duration_mins  Source_Banglore  Source_Kolkata  \
# 0               2             50                0               0
# 1               7             25                0               0
# 2              19              0                0               0
#
#    Source_Delhi  Source_Chennai  Source_Mumbai
# 0             0               0              0
# 1             0               0              0
# 2             0               0              0

# %%
data.columns
# Out:
# Index(['Airline', 'Destination', 'Total_Stops', 'Price', 'Journey_month',
#        'Journey_day', 'Dep_Time_hour', 'Dep_Time_minute', 'Arrival_Time_hour',
#        'Arrival_Time_minute', 'Duration_hours', 'Duration_mins',
#        'Source_Banglore', 'Source_Kolkata', 'Source_Delhi', 'Source_Chennai',
#        'Source_Mumbai'],
#       dtype='object')

# %%
def plot(df, col):
    fig, (ax1, ax2, ax3)=plt.subplots(3,1)
    sns.distplot(df[col], ax=ax1)
    sns.boxplot(x=df[col], ax=ax2)
    sns.distplot(df[col], ax=ax3, kde=False)

# %%
plot(data , 'Price')

# %%
q1=data['Price'].quantile(0.25)
q3=data['Price'].quantile(0.75)
iqr = q3-q1
maximum=q3 + 1.5*iqr
minimum=q1 - 1.5*iqr

# %%
print(maximum)
# Out:
# 23017.0

# %%
print(minimum)
# Out:
# -5367.0

# %%
print([price for price in data['Price'] if price>maximum or price<minimum])
# Out:
# [27430, 36983, 26890, 26890, 25139, 27210, 52229, 26743, 26890, 25735, 27992, 26890, 26890, 23583, 26890, 23533, 24115, 25735, 54826, 31783, 27992, 26890, 26890, 25430, 36235, 27210, 26890, 25735, 54826, 26890, 35185, 79512, 28097, 27992, 26890, 25735, 26092, 31825, 25913, 25735, 27992, 31825, 23267, 62427, 54826, 31825, 25430, 26890, 36235, 23843, 26890, 25735, 28322, 25735, 25735, 31825, 26890, 27992, 34273, 46490, 29528, 26890, 26890, 26890, 34503, 26890, 27992, 26890, 26890, 23170, 24528, 26890, 27992, 25735, 34608, 25703, 26890, 23528, 31825, 27282, 25735, 27992, 52285, 24017, 31945, 26890, 24318, 23677, 27992, 24210, 57209, 26890, 31825, 26480]

# %%
len([price for price in data['Price'] if price>maximum or price<minimum])
# Out:
# 94

# %%
data['Price'] = np.where(data['Price']>=35000, data['Price'].median(), data['Price'])

# %%
plot(data, 'Price')

# %%
X = data.drop(['Price'], axis=1)

# %%
y = data['Price']

# %%
from sklearn.feature_selection import mutual_info_regression

# %%
imp = mutual_info_regression(X, y)

# %%
imp
# Out:
# array([1.31391391e+00, 1.07418477e+00, 7.91468799e-01, 6.26890433e-01,
#        3.79476745e-01, 9.24994961e-01, 7.56259583e-01, 1.14844026e+00,
#        9.00572202e-01, 1.11663441e+00, 6.76104060e-01, 0.00000000e+00,
#        0.00000000e+00, 1.15962353e-03, 5.69890227e-03, 0.00000000e+00])

# %%
imp_df = pd.DataFrame(imp, index=X.columns)

# %%
imp_df
# Out:
#                             0
# Airline              1.313914
# Destination          1.074185
# Total_Stops          0.791469
# Journey_month        0.626890
# Journey_day          0.379477
# Dep_Time_hour        0.924995
# Dep_Time_minute      0.756260
# Arrival_Time_hour    1.148440
# Arrival_Time_minute  0.900572
# Duration_hours       1.116634
# Duration_mins        0.676104
# Source_Banglore      0.000000
# Source_Kolkata       0.000000
# Source_Delhi         0.001160
# Source_Chennai       0.005699
# Source_Mumbai        0.000000

# %%
imp_df.columns = ['importance']

# %%
imp_df
# Out:
#                      importance
# Airline                1.313914
# Destination            1.074185
# Total_Stops            0.791469
# Journey_month          0.626890
# Journey_day            0.379477
# Dep_Time_hour          0.924995
# Dep_Time_minute        0.756260
# Arrival_Time_hour      1.148440
# Arrival_Time_minute    0.900572
# Duration_hours         1.116634
# Duration_mins          0.676104
# Source_Banglore        0.000000
# Source_Kolkata         0.000000
# Source_Delhi           0.001160
# Source_Chennai         0.005699
# Source_Mumbai          0.000000

# %%
imp_df.sort_values(by='importance', ascending=False)
# Out:
#                      importance
# Airline                1.313914
# Arrival_Time_hour      1.148440
# Duration_hours         1.116634
# Destination            1.074185
# Dep_Time_hour          0.924995
# Arrival_Time_minute    0.900572
# Total_Stops            0.791469
# Dep_Time_minute        0.756260
# Duration_mins          0.676104
# Journey_month          0.626890
# Journey_day            0.379477
# Source_Chennai         0.005699
# Source_Delhi           0.001160
# Source_Banglore        0.000000
# Source_Kolkata         0.000000
# Source_Mumbai          0.000000

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.25, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
ml_model = RandomForestRegressor()

# %%
ml_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = ml_model.predict(X_test)

# %%
y_pred
# Out:
# array([16832.09,  5403.56,  8729.45, ...,  3522.17,  6103.63,  6830.85])

# %%
from sklearn import metrics

# %%
metrics.r2_score(y_test, y_pred)
# Out:
# 0.8081273837928448

# %%
import pickle

# %%
file = open('rf_random.pkl', 'wb')

# %%
pickle.dump(ml_model, file)

# %%
with open('rf_random.pkl', 'rb') as model:
    forest = pickle.load(model)

# %%
y_pred2 = forest.predict(X_test)

# %%
metrics.r2_score(y_test, y_pred2)
# Out:
# 0.8081273837928448

# %%
def mape(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
mape(y_test, y_pred) # the true values are inside y_test,  # mean absolute percent error
# Out:
# 13.313655590816825

# %%
from sklearn import metrics

# %%
def predict(ml_model):
    model = ml_model.fit(X_train, y_train)
    print('Training score : {}'.format(model.score(X_train, y_train)))
    y_prediction = model.predict(X_test)
    print('Predictions are : {}'.format(y_prediction))
    print('\n')
    r2_score = metrics.r2_score(y_test, y_prediction)
    print('r2 score : {}'.format(r2_score))
    print('MAE : {}'.format(metrics.mean_absolute_error(y_test, y_prediction)))
    print('MSE : {}'.format(metrics.mean_squared_error(y_test, y_prediction)))
    print('RMSE : {}'.format(np.sqrt(metrics.mean_squared_error(y_test, y_prediction))))
    print('MAPE : {}'.format(mape(y_test, y_prediction)))
    sns.distplot(y_test - y_prediction)

# %%
predict(RandomForestRegressor())
# Out:
# Training score : 0.9518190719676366
# Predictions are : [16870.8   5336.24  8947.69 ...  3521.12  6388.18  6771.37]
#
#
# r2 score : 0.8099370225880477
# MAE : 1179.1811171545912
# MSE : 3700069.955475579
# RMSE : 1923.556590141184
# MAPE : 13.226981066371337

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
predict(DecisionTreeRegressor())
# Out:
# Training score : 0.966591628243878
# Predictions are : [16840.  4959.  8610. ...  3419.  5797.  6442.]
#
#
# r2 score : 0.6770763819651219
# MAE : 1415.240796206165
# MSE : 6286547.718415284
# RMSE : 2507.2988889271423
# MAPE : 15.64069789481486

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
reg_rf = RandomForestRegressor()

# %%
np.linspace(start=100, stop=1200, num=6)
# Out:
# array([ 100.,  320.,  540.,  760.,  980., 1200.])

# %%
n_estimators = [int(x) for x in np.linspace(start=100, stop=1200, num=8)]
max_features = ["auto", "sqrt"]
max_depth = [int(x) for x in np.linspace(start=5, stop=40, num=4)] 
min_samples_split = [5,10,15,100]

# %%
random_grid = {
    'n_estimators':n_estimators,
    'max_features':max_features,
    'max_depth':max_depth,
    'min_samples_split':min_samples_split
}

# %%
random_grid
# Out:
# {'n_estimators': [100, 257, 414, 571, 728, 885, 1042, 1200],
#  'max_features': ['auto', 'sqrt'],
#  'max_depth': [5, 16, 28, 40],
#  'min_samples_split': [5, 10, 15, 100]}

# %%
rf_random= RandomizedSearchCV(estimator=reg_rf, param_distributions=random_grid, cv=3, n_jobs=-1, verbose=2)

# %%
rf_random.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# RandomizedSearchCV(cv=3, estimator=RandomForestRegressor(), n_jobs=-1,
#                    param_distributions={'max_depth': [5, 16, 28, 40],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_split': [5, 10, 15, 100],
#                                         'n_estimators': [100, 257, 414, 571,
#                                                          728, 885, 1042,
#                                                          1200]},
#                    verbose=2)

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 257,
#  'min_samples_split': 10,
#  'max_features': 'sqrt',
#  'max_depth': 40}

# %%
rf_random.best_estimator_
# Out:
# RandomForestRegressor(max_depth=40, max_features='sqrt', min_samples_split=10,
#                       n_estimators=257)

# %%
rf_random.best_score_
# Out:
# 0.801383329003096
